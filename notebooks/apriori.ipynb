# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np

from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules

# %% [markdown]
# # Data Load

# %%
df_aisles = pd.read_csv('../data/aisles.csv')
df_departments = pd.read_csv('../data/departments.csv')
df_orders = pd.read_csv('../data/orders.csv')
df_products = pd.read_csv('../data/products.csv')
df_order_products_prior = pd.read_csv('../data/order_products__prior.csv')
df_order_products_train = pd.read_csv('../data/order_products__train.csv')

# %% [markdown]
# # Sample Order

# %%
np.random.seed(42)

NUM_ORDERS_SAMPLE = 10000

unique_orders = df_orders['order_id'].unique()
total_unique_orders = len(unique_orders)

sampled_orders_id = np.random.choice(unique_orders, size=NUM_ORDERS_SAMPLE, replace=False)

df_order_products_prior_sample = df_order_products_prior[df_order_products_prior['order_id'].isin(sampled_orders_id)]

# %%
df_market = pd.merge(
    df_order_products_prior_sample,
    df_products,
    on='product_id',
    how='left'
)

df_market_aisles = pd.merge(
    df_market,
    df_aisles,on='aisle_id',
    how='left'
)

df_full = pd.merge(
    df_market_aisles,
    df_departments,
    on='department_id',
    how='left'
)

# %%
df_full
# Out:
#        order_id  product_id  add_to_cart_order  reordered  \
# 0           322       13819                  1          1
# 1           322         432                  2          1
# 2           322       19311                  3          1
# 3           322       36646                  4          0
# 4           322       28842                  5          1
# ...         ...         ...                ...        ...
# 96598   3420968       40708                  6          0
# 96599   3420968       39275                  7          0
# 96600   3420968       29487                  8          1
# 96601   3420968       24852                  9          1
# 96602   3420968       48679                 10          1
#
#                             product_name  aisle_id  department_id  \
# 0                 Roasted Salted Cashews       117             19
# 1      Vanilla Almond Breeze Almond Milk        91             16
# 2                 Almond Flour Tortillas       128              3
# 3                Lactose Free Sour Cream       108             16
# 4                       Bunched Cilantro        16              4
# ...                                  ...       ...            ...
# 96598                             Fennel        83              4
# 96599                Organic Blueberries       123              4
# 96600                        Roma Tomato        83              4
# 96601                             Banana        24              4
# 96602  Organic Garnet Sweet Potato (Yam)        83              4
#
#                             aisle  department
# 0          nuts seeds dried fruit      snacks
# 1                 soy lactosefree  dairy eggs
# 2            tortillas flat bread      bakery
# 3            other creams cheeses  dairy eggs
# 4                     fresh herbs     produce
# ...                           ...         ...
# 96598            fresh vegetables     produce
# 96599  packaged vegetables fruits     produce
# 96600            fresh vegetables     produce
# 96601                fresh fruits     produce
# 96602            fresh vegetables     produce
#
# [96603 rows x 9 columns]

# %% [markdown]
# # 1.0 Análise Descritiva

# %% [markdown]
# ## 1.1 Dimensão dos Dados

# %%
print('Quantidade de Linhas: {}'.format(df_full.shape[0]))
print('Quantidade de Colunas: {}'.format(df_full.shape[1]))
# Out:
# Quantidade de Linhas: 96603
# Quantidade de Colunas: 9

# %% [markdown]
# ## 1.2 Tipo dos Dados

# %%
df_full.dtypes
# Out:
# order_id              int64
# product_id            int64
# add_to_cart_order     int64
# reordered             int64
# product_name         object
# aisle_id              int64
# department_id         int64
# aisle                object
# department           object
# dtype: object

# %% [markdown]
# ## 1.3 Check Na

# %%
df_full.isna().sum()
# Out:
# order_id             0
# product_id           0
# add_to_cart_order    0
# reordered            0
# product_name         0
# aisle_id             0
# department_id        0
# aisle                0
# department           0
# dtype: int64

# %% [markdown]
# # 2.0 Exploratory Data Analysis (EDA)

# %%
##### Tamanho da Cesta de Compras #####7
basket_sizes = df_full.groupby('order_id').size()
print(basket_sizes.describe())
print()
print('Em média o tamanho do carrinho de compras é de {:.2f} itens'.format(basket_sizes.mean()))
# Out:
# count    9414.000000
# mean       10.261632
# std         7.645446
# min         1.000000
# 25%         5.000000
# 50%         8.000000
# 75%        14.000000
# max        72.000000
# dtype: float64
#
# Em média o tamanho do carrinho de compras é de 10.26 itens

# %%
basket_size_category = df_full.groupby(['order_id', 'department']).size()

# %%
basket_size_category = df_full[['order_id', 'department']].groupby('order_id').nunique().reset_index()
print(f'Tamanho médio da cesta de compras em departamentos: {basket_size_category["department"].mean():.2f}')
print(f'Tamanha minimo da cesta de compras em departamentos: {basket_size_category["department"].min():.2f}')
print(f'Tamanho maximo da cesta de compras em departamentos: {basket_size_category["department"].max():.2f}')
print(f'Mediana do tamanho da cesta de compras em departamentos: {basket_size_category["department"].median():.2f}')
# Out:
# Tamanho médio da cesta de compras em departamentos: 4.80
# Tamanha minimo da cesta de compras em departamentos: 1.00
# Tamanho maximo da cesta de compras em departamentos: 15.00
# Mediana do tamanho da cesta de compras em departamentos: 5.00

# %% [markdown]
# # 3.0 Data Preparation

# %%
transactions = df_full.groupby('order_id')['product_name'].apply(list).reset_index()
transactions_list = transactions['product_name'].tolist()

# %%
te = TransactionEncoder()
transactions_encoded = te.fit(transactions_list).transform(transactions_list)

df_encoded = pd.DataFrame(transactions_encoded, columns=te.columns_)

# %%
min_support = 0.003
min_confidence = 0.01
min_lift = 0.4

frequent_itemsets = apriori(
    df_encoded,
    min_support=min_support,
    use_colnames=True,
    verbose=1
)
# Out:
# Processing 76 combinations | Sampling itemset size 4e 32

# %%
frequent_itemsets
# Out:
#       support                                           itemsets
# 0    0.004461                         (0% Greek Strained Yogurt)
# 1    0.004355                                   (1% Lowfat Milk)
# 2    0.013278                           (100% Raw Coconut Water)
# 3    0.008710                       (100% Recycled Paper Towels)
# 4    0.020289                           (100% Whole Wheat Bread)
# ..        ...                                                ...
# 822  0.003399    (Banana, Organic Baby Spinach, Organic Avocado)
# 823  0.004037    (Banana, Organic Strawberries, Organic Avocado)
# 824  0.003081  (Banana, Organic Strawberries, Organic Whole M...
# 825  0.003081  (Organic Strawberries, Organic Hass Avocado, O...
# 826  0.003293  (Organic Raspberries, Organic Strawberries, Or...
#
# [827 rows x 2 columns]

# %%
rules =association_rules(
    frequent_itemsets,
    metric='confidence',
    min_threshold=min_confidence
)
print(f'Total de Regras: {len(rules)}')

ant_sizes = rules['antecedents'].apply(len)
conseq_sizes = rules['consequents'].apply(len)

recommendations = rules[
    (ant_sizes == 1) &
    (conseq_sizes >=2)
].copy()

print('Total de Recomendações: {}'.format(len(recommendations)))
# Out:
# Total de Regras: 658
# Total de Recomendações: 30

# %%
recommendations
# Out:
#                   antecedents                                     consequents  \
# 601  (Bag of Organic Bananas)    (Organic Hass Avocado, Organic Baby Spinach)
# 602    (Organic Hass Avocado)  (Bag of Organic Bananas, Organic Baby Spinach)
# 603    (Organic Baby Spinach)  (Bag of Organic Bananas, Organic Hass Avocado)
# 607     (Organic Raspberries)  (Bag of Organic Bananas, Organic Hass Avocado)
# 608  (Bag of Organic Bananas)     (Organic Raspberries, Organic Hass Avocado)
# 609    (Organic Hass Avocado)   (Organic Raspberries, Bag of Organic Bananas)
# 613  (Bag of Organic Bananas)    (Organic Strawberries, Organic Hass Avocado)
# 614    (Organic Strawberries)  (Bag of Organic Bananas, Organic Hass Avocado)
# 615    (Organic Hass Avocado)  (Bag of Organic Bananas, Organic Strawberries)
# 619     (Organic Raspberries)  (Bag of Organic Bananas, Organic Strawberries)
# 620  (Bag of Organic Bananas)     (Organic Raspberries, Organic Strawberries)
# 621    (Organic Strawberries)   (Organic Raspberries, Bag of Organic Bananas)
# 625                  (Banana)                        (Limes, Organic Avocado)
# 626                   (Limes)                       (Banana, Organic Avocado)
# 627         (Organic Avocado)                                 (Banana, Limes)
# 631                  (Banana)         (Organic Baby Spinach, Organic Avocado)
# 632    (Organic Baby Spinach)                       (Banana, Organic Avocado)
# 633         (Organic Avocado)                  (Banana, Organic Baby Spinach)
# 637                  (Banana)         (Organic Strawberries, Organic Avocado)
# 638    (Organic Strawberries)                       (Banana, Organic Avocado)
# 639         (Organic Avocado)                  (Banana, Organic Strawberries)
# 643                  (Banana)      (Organic Strawberries, Organic Whole Milk)
# 644    (Organic Strawberries)                    (Banana, Organic Whole Milk)
# 645      (Organic Whole Milk)                  (Banana, Organic Strawberries)
# 649    (Organic Strawberries)    (Organic Hass Avocado, Organic Baby Spinach)
# 650    (Organic Hass Avocado)    (Organic Strawberries, Organic Baby Spinach)
# 651    (Organic Baby Spinach)    (Organic Strawberries, Organic Hass Avocado)
# 655     (Organic Raspberries)    (Organic Strawberries, Organic Hass Avocado)
# 656    (Organic Strawberries)     (Organic Raspberries, Organic Hass Avocado)
# 657    (Organic Hass Avocado)     (Organic Raspberries, Organic Strawberries)
#
#      antecedent support  consequent support   support  confidence      lift  \
# 601            0.118122            0.014871  0.004461    0.037770  2.539748
# 602            0.070215            0.015721  0.004461    0.063540  4.041665
# 603            0.076801            0.021245  0.004461    0.058091  2.734357
# 607            0.042490            0.021245  0.004355    0.102500  4.824675
# 608            0.118122            0.008923  0.004355    0.036871  4.132130
# 609            0.070215            0.014022  0.004355    0.062027  4.423669
# 613            0.118122            0.013491  0.004568    0.038669  2.866382
# 614            0.085723            0.021245  0.004568    0.053284  2.508067
# 615            0.070215            0.018271  0.004568    0.065053  3.560514
# 619            0.042490            0.018271  0.004249    0.100000  5.473256
# 620            0.118122            0.011579  0.004249    0.035971  3.106726
# 621            0.085723            0.014022  0.004249    0.049566  3.534978
# 625            0.147652            0.007542  0.003081    0.020863  2.766299
# 626            0.047801            0.017740  0.003081    0.064444  3.632814
# 627            0.053112            0.011154  0.003081    0.058000  5.200114
# 631            0.147652            0.009242  0.003399    0.023022  2.491094
# 632            0.076801            0.017740  0.003399    0.044260  2.494993
# 633            0.053112            0.016040  0.003399    0.064000  3.990040
# 637            0.147652            0.007330  0.004037    0.027338  3.729872
# 638            0.085723            0.017740  0.004037    0.047088  2.654409
# 639            0.053112            0.018164  0.004037    0.076000  4.184000
# 643            0.147652            0.009029  0.003081    0.020863  2.310673
# 644            0.085723            0.009348  0.003081    0.035936  3.844289
# 645            0.045995            0.018164  0.003081    0.066975  3.687128
# 649            0.085723            0.014871  0.003081    0.035936  2.416410
# 650            0.070215            0.012641  0.003081    0.043873  3.470754
# 651            0.076801            0.013491  0.003081    0.040111  2.973241
# 655            0.042490            0.013491  0.003293    0.077500  5.744764
# 656            0.085723            0.008923  0.003293    0.038414  4.305098
# 657            0.070215            0.011579  0.003293    0.046899  4.050493
#
#      representativity  leverage  conviction  zhangs_metric   jaccard  \
# 601               1.0  0.002705    1.023797       0.687465  0.034711
# 602               1.0  0.003358    1.051063       0.809410  0.054759
# 603               1.0  0.002830    1.039119       0.687049  0.047673
# 607               1.0  0.003453    1.090535       0.827910  0.073345
# 608               1.0  0.003301    1.029018       0.859523  0.035498
# 609               1.0  0.003371    1.051180       0.832389  0.054521
# 613               1.0  0.002974    1.026191       0.738343  0.035953
# 614               1.0  0.002746    1.033842       0.657664  0.044606
# 615               1.0  0.003285    1.050037       0.773449  0.054430
# 619               1.0  0.003473    1.090810       0.853561  0.075188
# 620               1.0  0.002881    1.025303       0.768947  0.033870
# 621               1.0  0.003047    1.037398       0.784350  0.044494
# 625               1.0  0.001967    1.013605       0.749115  0.020251
# 626               1.0  0.002233    1.049922       0.761113  0.049320
# 627               1.0  0.002488    1.049731       0.853001  0.050347
# 631               1.0  0.002035    1.014105       0.702260  0.022145
# 632               1.0  0.002037    1.027749       0.649044  0.037296
# 633               1.0  0.002547    1.051239       0.791410  0.051696
# 637               1.0  0.002954    1.020571       0.858681  0.026742
# 638               1.0  0.002516    1.030799       0.681706  0.040598
# 639               1.0  0.003072    1.062593       0.803680  0.060032
# 643               1.0  0.001747    1.012086       0.665486  0.020055
# 644               1.0  0.002279    1.027579       0.809245  0.033487
# 645               1.0  0.002245    1.052314       0.763923  0.050435
# 649               1.0  0.001806    1.021849       0.641122  0.031590
# 650               1.0  0.002193    1.032665       0.765637  0.038615
# 651               1.0  0.002044    1.027732       0.718877  0.035323
# 655               1.0  0.002720    1.069387       0.862579  0.062500
# 656               1.0  0.002528    1.030669       0.839699  0.036047
# 657               1.0  0.002480    1.037058       0.809990  0.041949
#
#      certainty  kulczynski
# 601   0.023244    0.168885
# 602   0.048583    0.173662
# 603   0.037646    0.134046
# 607   0.083019    0.153750
# 608   0.028199    0.262483
# 609   0.048688    0.186317
# 613   0.025523    0.188626
# 614   0.032734    0.134142
# 615   0.047653    0.157526
# 619   0.083250    0.166279
# 620   0.024678    0.201472
# 621   0.036050    0.176298
# 625   0.013423    0.214657
# 626   0.047548    0.119049
# 627   0.047375    0.167095
# 631   0.013909    0.195419
# 632   0.026999    0.117938
# 633   0.048742    0.137960
# 637   0.020156    0.289031
# 638   0.029878    0.137316
# 639   0.058906    0.149111
# 643   0.011942    0.181020
# 644   0.026839    0.182741
# 645   0.049713    0.118283
# 649   0.021382    0.121539
# 650   0.031632    0.143785
# 651   0.026984    0.134229
# 655   0.064885    0.160797
# 656   0.029757    0.203731
# 657   0.035734    0.165651
